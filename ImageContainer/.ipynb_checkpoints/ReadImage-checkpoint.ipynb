# %%
from PIL import Image
import numpy

# %%
im = Image.open('image001.tif')
x = numpy.array(im)
x[-1,:]

# %%
imarray
# Out:
# array([[4027, 4114, 4416, ..., 4114, 4848, 4416],
#        [4027, 4114, 4416, ..., 4114, 4848, 4416],
#        [5539, 5928, 5928, ..., 3411, 4071, 3898],
#        ...,
#        [4978, 4373, 3984, ..., 4632, 4071, 3731],
#        [5280, 5496, 5409, ..., 4762, 4502, 4027],
#        [5496, 5366, 5366, ..., 4330, 3569, 3770]], dtype=uint16)

# %%
im = Image.open('image002.tif')
x = numpy.array(im)
x[-1,:]
# Out:
# array([ 4978,  4848,  5323,  6014,  6748,  7569,  8476,  8303,  7698,
#         6273,  5755,  5539,  5539,  4891,  3691,  3080,  3346,  3770,
#         4027,  3204,  2712,  2105,  2040,  2529,  3156,  3476,  3075,
#         2976,  3529,  4762,  5539,  6230,  6921,  7007,  7007,  7007,
#         6230,  5755,  5107,  4287,  4546,  5625,  7439,  8778,  8519,
#         6360,  3753,  2721,  5064,  8260, 11240, 11456,  9426,  6316,
#         4027,  3061,  3795,  3745,  3319,  2885,  2442,  1828,  1794,
#         2228,  2511,  2596,  2504,  2238,  2303,  2452,  2282,  2139,
#         2089,  2836,  3839,  3777,  2920,  2425,  2351,  2517,  2311,
#         1861,  1817,  2336,  2712,  2406,  1940,  1666,  2159,  2630,
#         2748,  3134,  5625,  8908, 11628, 12665, 10030,  6575,  4287,
#         4416,  4762,  4589,  3028,  2538,  3039,  3941,  4330,  3811,
#         2660,  2133,  2197,  2494,  2698,  2650,  2883,  3012,  2872,
# ...

# %%
im = Image.open('image002.tif')
x = numpy.array(im)
x[-1,:]
# Out:
# array([[3162, 3038, 3709, ..., 4675, 5107, 4632],
#        [3162, 3038, 3709, ..., 4675, 5107, 4632],
#        [4114, 4243, 4287, ..., 4114, 4459, 3855],
#        ...,
#        [4546, 4675, 4330, ..., 4675, 4243, 3733],
#        [5712, 5798, 5409, ..., 4632, 4157, 3855],
#        [5755, 5539, 5669, ..., 4157, 3215, 3262]], dtype=uint16)
